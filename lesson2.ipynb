# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### CREATING DATAFRAMES IN PANDAS
# * FROM SCRATCH
#     1. LIST OF LISTS
#     2. DICTIONARIES
# * LOAD A LOCAL FILE
# * CONNECTING TO DATABASE
# * CONNECT TO API

# %%
 # LIST OF LISTS

states = [
    ['lagos', 'ikeja', 32, 345600],
    ['kwara', 'ilorin', 16, 223000],
    ['osun', 'osogbo', 27, 563530],
    ['kano', 'kano', 44, 45463287]
]

column_name = ['states', 'capital', 'lga', 'population']

data = pd.DataFrame(data = states, columns = column_name)

data
# Out:
#   states capital  lga  population
# 0  lagos   ikeja   32      345600
# 1  kwara  ilorin   16      223000
# 2   osun  osogbo   27      563530
# 3   kano    kano   44    45463287

# %%
# from Dictionaries

clubs = {
    'name': ['chealsea', 'man city', 'arsenal', 'liverpool', 'bayer leverkusen'],
    'best player': ['palmer', 'debruyne', 'saka', 'endo', 'boniface'],
    'coach': ['pouch', 'pep', 'mikel', 'klopp', 'xabi'],
    'ucl': [2, 1, 0.000, 6, 0],
    'stadium': ['Bridge','Etihad','Emirates', 'Anfield', 'Bayarena']
}

club_df = pd.DataFrame(data = clubs)

club_df
# Out:
#                name best player  coach  ucl   stadium
# 0          chealsea      palmer  pouch  2.0    Bridge
# 1          man city    debruyne    pep  1.0    Etihad
# 2           arsenal        saka  mikel  0.0  Emirates
# 3         liverpool        endo  klopp  6.0   Anfield
# 4  bayer leverkusen    boniface   xabi  0.0  Bayarena

# %%
# Loading local files

data = pd.read_csv('credit card customers.csv')

data
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
import mysql.connector
from mysql.connector import Error

# %%
def connect_db(host_name, user_name, db_name, password):
    connection = None
    try:
        connection = mysql.connector.connect(
            host = host_name,
            user = user_name,
            database = db_name,
            passwd = password
        )
        print(f'connected to mysql database {db_name} successfully')
    except Error as err:
        print (f'Error: {err}')
    return connection
# define a read query function

def read_query(connection, query):
    result = None
    cursor = connection.cursor()

    try: 
        cursor.execute(query)
        result = cursor.fetchall()
    except Error as err:
        print(f'Error: {err}')
    return result

# %%
connection = connect_db(host_name = 'localhost', user_name = 'root',
                        db_name = 'northwind', password = '1234') 

query1 = '''

select orderid, freight, shipcountry
from orders
limit 100;

'''
data = read_query(connection = connection, query = query1)

data

# convert to spreadsheet

data_list = []
for row in data:
    row = list(row)
    data_list.append(row)

    orders_df = pd.DataFrame(data = data_list, columns = ['orderid', 'freight', 'country'])

    orders_df
# Out:
# connected to mysql database northwind successfully

# %%
connection
print(connection)

# %%
orders_df
# Out:
#     orderid   freight  country
# 0     10248   32.3800   France
# 1     10249   11.6100  Germany
# 2     10250   65.8300   Brazil
# 3     10251   41.3400   France
# 4     10252   51.3000  Belgium
# ..      ...       ...      ...
# 95    10343  110.3700  Germany
# 96    10344   23.2900      USA
# 97    10345  249.0600  Germany
# 98    10346  142.0800      USA
# 99    10347    3.1000   Brazil
#
# [100 rows x 3 columns]

# %%
# ASSIGNMENT:
# Create a dataframe of columns: name, gender, salary, age, occupation containing 10 rows of data Using
# 1. list of list approach
# 2. Dictionary approach.

# Go to kaggle.com//dataset and download any 2 dataset of your choice and load them into python

# %%
import pandas as pd
import numpy as np

# List of List


organogram = [
    ['Banjo', 'Male', 100000, 40, ' HR'],
    ['Taiwo', 'Male', 75000, 50, 'HR Asst'],
    ['Dupe', 'Female', 120000, 35, 'secretary'],
    ['Dairo', 'Female', 56000, 29, 'Office asst'],
    ['Kehinde', 'Male', 145000, 31, 'sales rep'],
    ['Taiwo', 'Female', 250000, 35, 'Marketing'],
    ['Tolani', 'Male', 125000, 35, 'sales rep'],
    ['Haleemah', 'Female', 250000, 35, 'sales rep'],
    ['Habeeebah', 'Female', 129000, 32, 'sales rep'],
    ['Christiana', 'Female', 340000, 39, 'Manager']
]

column_name = ['name', 'gender', 'salary', 'age', 'occupation']

data = pd.DataFrame(data = organogram, columns = column_name)

data
# Out:
#          name  gender  salary  age   occupation
# 0       Banjo    Male  100000   40           HR
# 1       Taiwo    Male   75000   50      HR Asst
# 2        Dupe  Female  120000   35    secretary
# 3       Dairo  Female   56000   29  Office asst
# 4     Kehinde    Male  145000   31    sales rep
# 5       Taiwo  Female  250000   35    Marketing
# 6      Tolani    Male  125000   35    sales rep
# 7    Haleemah  Female  250000   35    sales rep
# 8   Habeeebah  Female  129000   32    sales rep
# 9  Christiana  Female  340000   39      Manager

# %%
# from Dictionaries

family = {
    'name': ['Adesina', 'Adenike', 'Bisola', 'Kikelomo', 'Habeebah', 'Mardiyyah', 'Adeniyi', 'Fatimo', 'Mubeenah', 'Faizah'],
    'gender': ['Male', 'Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female', 'Female'],
    'salary': [500000, 250000, 0, 0, 0, 0, 285000, 125000, 0,0],
    'age': [42, 39, 13, 11, 6, 2, 35, 32, 5, 3],
    'occupation': ['sales', 'trading', 'student', 'student', 'student', 'student', 'marketing', 'trading', 'student', 'student']
}

family_df = pd.DataFrame(data = family)

family_df
# Out:
#         name  gender  salary  age occupation
# 0    Adesina    Male  500000   42      sales
# 1    Adenike  Female  250000   39    trading
# 2     Bisola  Female       0   13    student
# 3   Kikelomo  Female       0   11    student
# 4   Habeebah  Female       0    6    student
# 5  Mardiyyah  Female       0    2    student
# 6    Adeniyi    Male  285000   35  marketing
# 7     Fatimo  Female  125000   32    trading
# 8   Mubeenah  Female       0    5    student
# 9     Faizah  Female       0    3    student

# %%
# Loading local files

data = pd.read_csv('car_prices.csv')

data
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %%
data = pd.read_csv('netflix_titles.csv')

data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...
